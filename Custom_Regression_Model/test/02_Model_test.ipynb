# %%
from Regression_Model import Regression_Model
from Regression_test import The_Test
from sklearn.preprocessing import PolynomialFeatures
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression

# %%
Regressor=Regression_Model()
The_Test(600,1,2,10,42,Regressor)
# Out:
# The MSE validation error of the model is 92.54186887450936
# The RMSE validation error of the model is 9.619868443721534
# The MAE validation error of the model is 7.647017298410185
# The R2 value of the model on the validation set is 0.8589952685548925
#
# The MSE error of the model is 88.14878852982358
# The RMSE error of the model is 9.388758625602406
# The MAE error of the model is 7.500699146679108
# The R2 value of the model is 0.8552543326296973

# %% [markdown]
# <h3> Multiple features test</h3>

# %%
for num_f in range (2,6):
    print(f"The following are the results of the model with {num_f} features\n")
    The_Test(300,num_f,2,10,42,Regressor)
# Out:
# The following are the results of the model with 2 features
#
# The MSE validation error of the model is 120.70501728862433
# The RMSE validation error of the model is 10.986583513022797
# The MAE validation error of the model is 8.95841717442359
# The R2 value of the model on the validation set is 0.9796069035990512
#
# The MSE error of the model is 130.6551086227209
# The RMSE error of the model is 11.430446562699153
# The MAE error of the model is 9.260830254605894
# The R2 value of the model is 0.9807316810519996
#
# The following are the results of the model with 3 features
#
# The MSE validation error of the model is 111.84793110026595
# The RMSE validation error of the model is 10.57581822367735
# The MAE validation error of the model is 8.363990031133877
# The R2 value of the model on the validation set is 0.9856538731739752
#
# The MSE error of the model is 111.59085036890512
# The RMSE error of the model is 10.563657054680691
# ...

# %% [markdown]
# <h3> Varying size of the dataset</h3>

# %%
for num_S in range (1000,5000,1000):
    print(f"The following are the results of the model with {num_S} samples\n")
    The_Test(num_S,3,2,10,42,Regressor)
# Out:
# The following are the results of the model with 1000 samples
#
# The MSE validation error of the model is 103.74619799099393
# The RMSE validation error of the model is 10.18558775873999
# The MAE validation error of the model is 8.255303527376565
# The R2 value of the model on the validation set is 0.993554908001374
#
# The MSE error of the model is 109.4258433957184
# The RMSE error of the model is 10.460680828498612
# The MAE error of the model is 8.550346009629056
# The R2 value of the model is 0.9923125677860382
#
# The following are the results of the model with 2000 samples
#
# The MSE validation error of the model is 101.14503141481599
# The RMSE validation error of the model is 10.057088615241291
# The MAE validation error of the model is 8.045054876452278
# The R2 value of the model on the validation set is 0.9377627668664612
#
# The MSE error of the model is 107.38123010895676
# The RMSE error of the model is 10.362491501031823
# ...

# %% [markdown]
# <h3> Variation in Noise</h3>

# %%
for noise in range (100,105):
    print(f"The following are the results of the model with {noise} for noise\n")
    The_Test(2000,3,2,10,42,Regressor)
# Out:
# The following are the results of the model with 100 for noise
#
# The MSE validation error of the model is 101.14503141481599
# The RMSE validation error of the model is 10.057088615241291
# The MAE validation error of the model is 8.045054876452278
# The R2 value of the model on the validation set is 0.9377627668664612
#
# The MSE error of the model is 107.38123010895676
# The RMSE error of the model is 10.362491501031823
# The MAE error of the model is 8.210815345594963
# The R2 value of the model is 0.9370936462916618
#
# The following are the results of the model with 101 for noise
#
# The MSE validation error of the model is 101.14503141481599
# The RMSE validation error of the model is 10.057088615241291
# The MAE validation error of the model is 8.045054876452278
# The R2 value of the model on the validation set is 0.9377627668664612
#
# The MSE error of the model is 107.38123010895676
# The RMSE error of the model is 10.362491501031823
# ...

# %% [markdown]
# <h4>Based on the tests done, the model seems to perform very well with different amounts of features, size of the dataset and varying amounts of noise.</h4>
